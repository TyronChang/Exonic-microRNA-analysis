# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

# %%
current_dir=os.getcwd()

# %%
human_exonic_miR_gene_type=pd.read_csv(f"{current_dir}/Human_csv_file/human_exonic_miR(gene_type)_NCBI_unique.csv")

human_exonic_miR_protein_coding = pd.read_csv(f'{current_dir}/Human_csv_file/human_exonic_miR_list(protein_coding_host_genes)_NCBI_unique.csv')

# %%
human_exonic_miR_gene_type.columns
# Out:
# Index(['hostgene_chrom', 'hostgene_exonStarts', 'hostgene_exonEnds',
#        'hostgene_cdsStart', 'hostgene_cdsEnd', 'hostgene_strand',
#        'hostgene_exonCounts', 'hostgene_txStarts', 'hostgene_txEnds',
#        'hostgene_Name', 'hostgene_NCBI_ID', 'miR_chrom', 'miR_name',
#        'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_strand', 'gene_type',
#        'pre_mRNA_length'],
#       dtype='object')

# %%
human_exonic_miR_protein_coding.columns
# Out:
# Index(['hostgene_NCBI_ID', 'hostgene_Name', 'hostgene_strand',
#        'hostgene_exonCounts', 'miR_name', 'miR_strand', 'region', 'gene_type',
#        'pre_mRNA_length'],
#       dtype='object')

# %%
exon_count_plots=sns.violinplot(x='gene_type', y='hostgene_exonCounts',data=human_exonic_miR_gene_type)
plt.xlabel('Gene type')
plt.ylabel('Exon counts')
plt.show()
# Out:
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(10, 6))
hue_order=['+','-']
exon_count_plots_strands=sns.violinplot(x='gene_type', y='hostgene_exonCounts',data=human_exonic_miR_gene_type,
                                        hue='hostgene_strand',hue_order=hue_order)
plt.xlabel('Gene type')
plt.ylabel('Exon counts')
plt.title('Exon counts in human host genes housed exonic miRNAs (violoin plots)')
plt.subplots_adjust(top=0.9, bottom=0.2, left=0.1, right=0.9)
plt.savefig(f"{current_dir}/Human_eps_file/Exon counts in human host genes housed exonic miRNAs_violoin_plots.eps")
plt.show()
# Out:
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(10, 6))
hue_order=['+','-']
exon_count_boxplots_strands=sns.boxplot(x='gene_type', y='hostgene_exonCounts',data=human_exonic_miR_gene_type,
                                        hue='hostgene_strand',width=0.3, hue_order=hue_order)
plt.xlabel('Gene type')
plt.ylabel('Exon counts')
plt.title('Exon counts in human host genes housed exonic miRNAs (boxplots)')
plt.subplots_adjust(hspace = 0.8)
plt.tight_layout()
plt.subplots_adjust(top=0.9, bottom=0.2, left=0.1, right=0.9)
plt.savefig(f"{current_dir}/Human_eps_file/Exon counts in human host genes housed exonic miRNAs_boxplots.eps")
plt.show()
# Out:
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(10, 6))
hue_order=['+','-']
exon_count_plots_strands=sns.violinplot(x='gene_type', y='pre_mRNA_length',data=human_exonic_miR_gene_type,
                                        hue='hostgene_strand',hue_order=hue_order)
plt.xlabel('Gene type')
plt.ylabel('host pre-mRNA length')
plt.title('pre-mRNA lenngth in human host genes housed exonic miRNAs (violoin plots)')
plt.subplots_adjust(top=0.9, bottom=0.2, left=0.1, right=0.9)
plt.savefig(f"{current_dir}/Human_eps_file/pre-mRNA lenngth in human host genes housed exonic miRNAs_violoin_plots.eps")
plt.show()
# Out:
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig, ax = plt.subplots(figsize=(10, 10)) 
exonic_mRNA_length_plots_strands=sns.violinplot(x='region', y=human_exonic_miR_protein_coding['pre_mRNA_length']/1000,
                                             data=human_exonic_miR_protein_coding, width=0.8, ax=ax)
plt.xticks(rotation=45,fontsize=8)
plt.tight_layout()
plt.xlabel('Region')
plt.ylabel('pre-mRNA length (kb)')
plt.figure(figsize=(10, 6))
plt.show()
# Out:
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
exonic_mRNA_length_plots_strands=sns.boxplot(x='region', y=human_exonic_miR_protein_coding['pre_mRNA_length']/1000,
                                             data=human_exonic_miR_protein_coding, width=0.3)
plt.xticks(rotation=45,fontsize=8)
plt.tight_layout()
plt.xlabel('Region')
plt.ylabel('pre-mRNA length (kb)')
plt.figure(figsize=(10, 6))
plt.show()
# Out:
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
hue_order=["+", "-"]
fig, ax = plt.subplots(figsize=(10, 10)) 
exonic_mRNA_length_plots_strands=sns.violinplot(x='region', y=human_exonic_miR_protein_coding['pre_mRNA_length']/1000,hue='hostgene_strand',
                                                hue_order=hue_order,data=human_exonic_miR_protein_coding, width=0.8, ax=ax)

plt.xticks(rotation=45,fontsize=8)
plt.tight_layout()
plt.xlabel('Region')
plt.ylabel('pre-mRNA length (kb)')
plt.title('pre-mRNA lenngth in human host genes housed exonic miRNAs with different regions (violoin plots)')
plt.subplots_adjust(top=0.9, bottom=0.2, left=0.1, right=0.9)
plt.savefig(f"{current_dir}/Human_eps_file/pre-mRNA lenngth in human host genes housed exonic miRNAs with different regions_violoin_plots.eps")
plt.show()
# Out:
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(figsize=(10, 6))
exonic_mRNA_length_plots_strands_box=sns.boxplot(x='region', y=human_exonic_miR_protein_coding['pre_mRNA_length']/1000,hue='hostgene_strand',hue_order=hue_order,
                                             data=human_exonic_miR_protein_coding, width=0.3,dodge=True)
plt.xticks(rotation=45,fontsize=8)
plt.tight_layout()
plt.xlabel('Region')
plt.ylabel('pre-mRNA length (kb)')
plt.title('pre-mRNA lenngth in human host genes housed exonic miRNAs with different regions (boxplots)')
plt.subplots_adjust(top=0.9, bottom=0.2, left=0.1, right=0.9)
plt.savefig(f"{current_dir}/Human_eps_file/pre-mRNA lenngth in human host genes housed exonic miRNAs with different regions_boxplots.eps")
plt.show()
# Out:
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Intronic

# %%
human_intronic_miR_gene_type=pd.read_csv(f"{current_dir}/Human_csv_file/human_intronic_miR(gene_type)_NCBI_unique.csv")

# %%
fig, ax = plt.subplots(figsize=(10, 10)) 
intronic_mRNA_length_plots=sns.violinplot(x='gene_type', y=human_intronic_miR_gene_type['pre_mRNA_length']/1000,
                                             data=human_intronic_miR_gene_type, width=0.8, ax=ax)
plt.xticks(rotation=45,fontsize=8)
plt.tight_layout()
plt.xlabel('Gene type')
plt.ylabel('pre-mRNA length (kb)')
plt.figure(figsize=(10, 6))
plt.show()
# Out:
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
fig, ax = plt.subplots(figsize=(10, 6)) 
intronic_mRNA_length_plots_strand=sns.violinplot(x='gene_type', y=human_intronic_miR_gene_type['pre_mRNA_length']/1000,hue='hostgene_strand',
                                             data=human_intronic_miR_gene_type, width=0.6, ax=ax)
plt.xticks(rotation=45,fontsize=8)
plt.tight_layout()
plt.xlabel('Gene type')
plt.ylabel('pre-mRNA length (kb)')
plt.title('pre-mRNA lenngth in human host genes housed intronic miRNAs with different regions (violoin plots)')
plt.subplots_adjust(top=0.9, bottom=0.2, left=0.1, right=0.9)
plt.savefig(f"{current_dir}/Human_eps_file/pre-mRNA lenngth in human host genes housed intronic miRNAs with different regions_violoin_plots.eps")
plt.show()
# Out:
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
hue_order=["+", "-"]
plt.figure(figsize=(10, 6))
intronic_mRNA_length_plots=sns.boxplot(x='gene_type', y=human_intronic_miR_gene_type['pre_mRNA_length']/1000,hue='hostgene_strand',
                                             data=human_intronic_miR_gene_type, width=0.3,hue_order=hue_order)
plt.xticks(rotation=45,fontsize=8)
plt.tight_layout()
plt.xlabel('Gene type')
plt.ylabel('pre-mRNA length (kb)')
plt.title('pre-mRNA lenngth in human host genes housed intronic miRNAs with different regions (boxplots)')
plt.subplots_adjust(top=0.9, bottom=0.2, left=0.1, right=0.9)
plt.savefig(f"{current_dir}/Human_eps_file/pre-mRNA lenngth in human host genes housed intronic miRNAs with different regions_boxplots.eps")
plt.show()
# Out:
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/tyronchang/opt/anaconda3/lib/python3.9/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
