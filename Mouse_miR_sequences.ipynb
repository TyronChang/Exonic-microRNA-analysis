# %%
import pandas as pd
import logomaker as lm
import matplotlib.pyplot as plt
import os
import re

# %%
current_dir=os.getcwd()

# %%
columns=["miR_name", "miR_ID", "pre-miRNA_sequences"]

# %%
mmu_miR_sequence=pd.read_csv(f"{current_dir}/Mouse_miR_sequence_fasta/mmu_miR_sequence.csv",header=None, names=columns)

# %%
mmu_miR_sequence["miR_name"]=mmu_miR_sequence["miR_name"].str.replace(">","")#### remove ">"

# %%
mmu_miR_sequence.to_csv(f"{current_dir}/Mouse_miR_sequence_fasta/mmu_miR_sequence.csv",index=False)

# %%
import import_ipynb
from EXONIC import Regions
# Out:
# importing Jupyter notebook from EXONIC.ipynb

# %%
mouse_exonic_miR=Regions(f"{current_dir}/Mouse_csv_file/mouse_exonic_miR(gene_type)_NCBI_unique.csv")

# %%
mouse_exonic_miR.df.columns
# Out:
# Index(['hostgene_chrom', 'hostgene_exonStarts', 'hostgene_exonEnds',
#        'hostgene_cdsStart', 'hostgene_cdsEnd', 'hostgene_strand',
#        'hostgene_exonCounts', 'hostgene_txStarts', 'hostgene_txEnds',
#        'hostgene_Name', 'hostgene_NCBI_ID', 'miR_chrom', 'miR_name',
#        'miR_exonStarts', 'miR_exonEnds', 'miR_type', 'miR_Name', 'miR_strand',
#        'gene_type', 'pre_mRNA_length'],
#       dtype='object')

# %%
mouse_exonic_miR.select(["hostgene_NCBI_ID",'hostgene_strand',
                            'pre_mRNA_length','miR_name','miR_strand', 'gene_type' ])

# %%
mouse_exonic_miR.df
# Out:
#     hostgene_NCBI_ID hostgene_strand  pre_mRNA_length  \
# 0     XM_047427799.1               -         209014.0
# 1        NR_132742.1               -          34328.0
# 2        NR_046105.1               -          61694.0
# 3     XM_047437906.1               -           4590.0
# 4        NM_006496.4               +          51581.0
# ..               ...             ...              ...
# 196      NM_052945.4               -           4775.0
# 197   XM_047441696.1               +          69285.0
# 198   XM_047441696.1               +          69285.0
# 199   XM_047441696.1               +          69285.0
# 200   XR_002958733.2               +          11753.0
#
#      mature_host_mRNA_Length      miR_name miR_strand            gene_type
# 0                      19460  hsa-mir-1843          -  protein-coding gene
# 1                       4157   hsa-mir-34a          -      non-coding gene
# 2                       2469   hsa-mir-137          -      non-coding gene
# 3                       4590  hsa-mir-2682          -  protein-coding gene
# 4                       9044   hsa-mir-197          +  protein-coding gene
# ..                       ...           ...        ...                  ...
# 196                     3923  hsa-mir-378i          -  protein-coding gene
# 197                    16367  hsa-let-7a-3          +  protein-coding gene
# 198                    16367  hsa-mir-4763          +  protein-coding gene
# 199                    16367    hsa-let-7b          +  protein-coding gene
# 200                    11634  hsa-mir-3619          +      non-coding gene
#
# [201 rows x 7 columns]

# %%
mouse_exonic_miR_sequence=mouse_exonic_miR.df.merge(mmu_miR_sequence, on="miR_name",how="inner")

# %%
mouse_exonic_miR_sequence.drop(columns=["miR_ID"], inplace=True)

# %%
mouse_exonic_miR_sequence.to_excel(f"{current_dir}/Mouse_miR_sequence_fasta/Mouse_exonic_miR_sequence_unique.xlsx",index=False)

# %%
mouse_exonic_miR_sequence.to_csv(f"{current_dir}/Mouse_miR_sequence_fasta/Mouse_exonic_miR_sequence_unique.csv",index=False)

# %%
mouse_exonic_miR_sequence
# Out:
#     hostgene_NCBI_ID hostgene_strand  pre_mRNA_length       miR_name  \
# 0        NR_015566.2               +          20510.0  mmu-mir-29b-2
# 1        NR_015566.2               +          20510.0    mmu-mir-29c
# 2        NR_131249.1               +          13077.0   mmu-mir-133b
# 3        NR_106184.1               -            147.0   mmu-mir-3535
# 4        NR_162775.1               -             66.0  mmu-mir-5104b
# ..               ...             ...              ...            ...
# 165      NR_162795.1               -             50.0  mmu-mir-12192
# 166      NM_019924.2               -          11544.0   mmu-mir-5046
# 167   XM_017318209.2               -          10733.0   mmu-mir-6990
# 168   XM_011247115.3               +           8151.0   mmu-mir-6991
# 169   XM_011247364.2               +          23379.0   mmu-mir-8092
#
#     miR_strand            gene_type  \
# 0            +      non-coding gene
# 1            +      non-coding gene
# 2            +      non-coding gene
# 3            -      non-coding gene
# 4            -      non-coding gene
# ..         ...                  ...
# 165          -      non-coding gene
# 166          -  protein-coding gene
# 167          -  protein-coding gene
# 168          +  protein-coding gene
# 169          +  protein-coding gene
#
#                                    pre-miRNA_sequences
# 0    CUUCUGGAAGCUGGUUUCACAUGGUGGCUUAGAUUUUUCCAUCUUU...
# 1    AUCUCUUACACAGGCUGACCGAUUUCUCCUGGUGUUCAGAGUCUGU...
# 2    CCUCCAAAGGGAGUGGCCCCCUGCUCUGGCUGGUCAAACGGAACCA...
# 3    UUUGGGGCUGUCUUUAUGUUGUUGCUGAGAAAAUGACAACUGGAUA...
# 4    UGGGCCAUCUCUUUAGUCCAGAAAUACUUUUUAUGAAACAAAUCAG...
# ..                                                 ...
# 165  UGUGGGGUAUAGCUAGAAAGAGAGAUUUCUUUCUAGCUAUACCCCA...
# 166  UCCUAGCUCCCGCCACUGUGACCCCCUUACCUUUAGGAGCUCCGAU...
# 167  GCUUGCCCAGGGUGAGUCAGGGCUCUCCUGUCAUCUGGGCCCCCUC...
# 168  AGCAGUGGAGAACAGGGACUGGGCCUGAUUGAUGGCACUCGCUCCA...
# 169  GCAGCGCGGCGCUCGGCUUUCCGGCAGUACCCGGAUGGAGGGGUAA...
#
# [170 rows x 7 columns]

# %% [markdown]
# ### Mature mouse miR sequences

# %%
human_exonic_miR_sequence_forfasta=Regions(f"{current_dir}/Human_miR_sequences_fasta/Human_exonic_miR_sequence_unique.csv")

# %%
human_exonic_miR_sequence_forfasta.select(['miR_name','pre-miRNA_sequences'])

# %%
human_exonic_miR_sequence_forfasta.df.to_csv(f"{current_dir}/Human_miR_sequences_fasta/Human_exonic_miR_sequence_forfasta.csv",index=False)

# %%
mature_columns=["miR_mature_name","miR_ID","genus", "species","miR_name2","mature_miR_sequences"]

# %%
human_mature_miR=pd.read_csv(f"{current_dir}/mature_miR/mature_miR.csv",header=None, names=mature_columns)

# %%
human_mature_miR.drop(columns=["miR_ID","genus", "species","miR_name2"],inplace=True)

# %%
human_mature_miR
# Out:
#           miR_mature_name    mature_miR_sequences
# 0            cel-let-7-5p  UGAGGUAGUAGGUUGUAUAGUU
# 1            cel-let-7-3p  CUAUGCAAUUUUCUACCUUACC
# 2            cel-lin-4-5p   UCCCUGAGACCUCAAGUGUGA
# 3            cel-lin-4-3p  ACACCUGGGCUCUCCGGGUACC
# 4            cel-miR-1-5p  CAUACUUCCUUACAUGCCCAUA
# ...                   ...                     ...
# 48880    smc-miR-12461-3p  AGUAAAUGAUCAGCAUCCUCCA
# 48881    gga-miR-1784b-5p  UUCUGCUCCUAUUUAAGUCAAU
# 48882    gga-miR-1784b-3p  UGAUUUCAAUAAGAGCAGAAUU
# 48883    mdo-miR-7385g-3p   AGCAUAGAAUGUCAGAUCUAG
# 48884  mdo-miR-7385g-2-3p   AGCAUAGAAUGUCAGGUCUAG
#
# [48885 rows x 2 columns]

# %%
human_mature_miR = human_mature_miR.loc[human_mature_miR['miR_mature_name'].str.contains(r'^hsa-', flags=re.I, regex=True)]

# %%
human_mature_miR
# Out:
#        miR_mature_name    mature_miR_sequences standard_id
# 112      hsa-let-7a-5p  UGAGGUAGUAGGUUGUAUAGUU          7a
# 113      hsa-let-7a-3p   CUAUACAAUCUACUGUCUUUC          7a
# 114    hsa-let-7a-2-3p  CUGUACAGCCUCCUAGCUUUCC          7a
# 115      hsa-let-7b-5p  UGAGGUAGUAGGUUGUGUGGUU          7b
# 116      hsa-let-7b-3p  CUAUACAACCUACUGCCUUCCC          7b
# ...                ...                     ...         ...
# 47417    hsa-miR-12131    UUUGGAGAGGUGUACUCCCA       12131
# 47418    hsa-miR-12132  UAUUACUGUGAGAAUUAUGAUG       12132
# 47419    hsa-miR-12133  CUUGGCACCAUUAAAAAGUACA       12133
# 47423    hsa-miR-12135      UAAAGGUUUGUUUGUAAA       12135
# 47424    hsa-miR-12136      GAAAAAGUCAUGGAGGCC       12136
#
# [2656 rows x 3 columns]

# %%
# Function to extract the relevant part from the identifier
def extract_id(identifier):
    match = re.search(r'(\d+[a-zA-Z]?)', identifier)
    return match.group(0) if match else None

# Standardize identifiers in df1
human_exonic_miR_sequence['standard_id'] = human_exonic_miR_sequence['miR_name'].apply(extract_id)

# Standardize identifiers in df2
human_mature_miR['standard_id'] = human_mature_miR['miR_mature_name'].apply(extract_id)

# Merge the dataframes on the standardized identifiers
merged_df = pd.merge(human_exonic_miR_sequence, human_mature_miR, on='standard_id', how='inner')
# Out:
# /var/folders/hz/4x5ldhv54fscy_nw6y5dbf2m0000gn/T/ipykernel_3116/1365459275.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   human_mature_miR['standard_id'] = human_mature_miR['miR_mature_name'].apply(extract_id)

# %%
merged_df
# Out:
#     hostgene_NCBI_ID hostgene_strand  pre_mRNA_length  \
# 0     XM_047427799.1               -         209014.0
# 1        NR_132742.1               -          34328.0
# 2        NR_132742.1               -          34328.0
# 3        NR_046105.1               -          61694.0
# 4        NR_046105.1               -          61694.0
# ..               ...             ...              ...
# 329   XM_047441696.1               +          69285.0
# 330   XM_047441696.1               +          69285.0
# 331   XM_047441696.1               +          69285.0
# 332   XR_002958733.2               +          11753.0
# 333   XR_002958733.2               +          11753.0
#
#      mature_host_mRNA_Length      miR_name miR_strand            gene_type  \
# 0                      19460  hsa-mir-1843          -  protein-coding gene
# 1                       4157   hsa-mir-34a          -      non-coding gene
# 2                       4157   hsa-mir-34a          -      non-coding gene
# 3                       2469   hsa-mir-137          -      non-coding gene
# 4                       2469   hsa-mir-137          -      non-coding gene
# ..                       ...           ...        ...                  ...
# 329                    16367  hsa-mir-4763          +  protein-coding gene
# 330                    16367    hsa-let-7b          +  protein-coding gene
# 331                    16367    hsa-let-7b          +  protein-coding gene
# 332                    11634  hsa-mir-3619          +      non-coding gene
# 333                    11634  hsa-mir-3619          +      non-coding gene
#
#                                    pre-miRNA_sequences standard_id  \
# 0    GCAGCGAUCCUACAUAAAUAUAUGGAGGUCUCUGUCUGGCUUAGGA...        1843
# 1    GGCCAGCUGUGAGUGUUUCUUUGGCAGUGUCUUAGCUGGUUGUUGU...         34a
# 2    GGCCAGCUGUGAGUGUUUCUUUGGCAGUGUCUUAGCUGGUUGUUGU...         34a
# 3    GGUCCUCUGACUCUCUUCGGUGACGGGUAUUCUUGGGUGGAUAAUA...         137
# 4    GGUCCUCUGACUCUCUUCGGUGACGGGUAUUCUUGGGUGGAUAAUA...         137
# ..                                                 ...         ...
# 329  CCUGUCCCUCCUGCCCUGCGCCUGCCCAGCCCUCCUGCUCUGGUGA...        4763
# 330  CGGGGUGAGGUAGUAGGUUGUGUGGUUUCAGGGCAGUGAUGUUGCC...          7b
# 331  CGGGGUGAGGUAGUAGGUUGUGUGGUUUCAGGGCAGUGAUGUUGCC...          7b
# 332  ACGGCAUCUUUGCACUCAGCAGGCAGGCUGGUGCAGCCCGUGGUGG...        3619
# 333  ACGGCAUCUUUGCACUCAGCAGGCAGGCUGGUGCAGCCCGUGGUGG...        3619
#
#      miR_mature_name      mature_miR_sequences
# 0       hsa-miR-1843      UAUGGAGGUCUCUGUCUGGC
# 1     hsa-miR-34a-5p    UGGCAGUGUCUUAGCUGGUUGU
# 2     hsa-miR-34a-3p    CAAUCAGCAAGUAUACUGCCCU
# 3     hsa-miR-137-5p   ACGGGUAUUCUUGGGUGGAUAAU
# 4     hsa-miR-137-3p   UUAUUGCUUAAGAAUACGCGUAG
# ..               ...                       ...
# 329  hsa-miR-4763-3p  AGGCAGGGGCUGGUGCUGGGCGGG
# 330    hsa-let-7b-5p    UGAGGUAGUAGGUUGUGUGGUU
# 331    hsa-let-7b-3p    CUAUACAACCUACUGCCUUCCC
# 332  hsa-miR-3619-5p    UCAGCAGGCAGGCUGGUGCAGC
# 333  hsa-miR-3619-3p    GGGACCAUCCUGCCUGCUGUGG
#
# [334 rows x 11 columns]

# %%
human_exonic_miR_sequence.shape
# Out:
# (201, 9)
